# %% [markdown]
# <a href="https://colab.research.google.com/github/msankar/cheat-at-search/blob/main/2_Synonyms_from_LLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Synonyms generation with an LLM
#
# <small>
# (from <a href="http://maven.com/softwaredoug/cheat-at-search">Cheat at Search with Agents</a> training course by Doug Turnbull.)
# </small>
#
# Let's get familiar with the code we'll use for this class by doing what a lot of search teams did when they heard about LLMs
#
# * Can I generate synonyms using LLMs?
#
# We'll try to expand queries -> their synonyms and see if it helps NDCG

# %%
# !pip install git+https://github.com/softwaredoug/cheat-at-search.git
# Out:
# Collecting git+https://github.com/softwaredoug/cheat-at-search.git
#   Cloning https://github.com/softwaredoug/cheat-at-search.git to /tmp/pip-req-build-quulb6uv
#   Running command git clone --filter=blob:none --quiet https://github.com/softwaredoug/cheat-at-search.git /tmp/pip-req-build-quulb6uv
#   Resolved https://github.com/softwaredoug/cheat-at-search.git to commit f00a5bb572fcc4c23e88b8f2f754e16ff5ba1c42
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets<5.0.0,>=4.8.4 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (4.8.5)
# Requirement already satisfied: google-genai<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (1.68.0)
# Requirement already satisfied: lxml<7.0.0,>=6.0.2 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (6.1.0)
# Requirement already satisfied: openai<2.0.0,>=1.84.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (1.109.1)
# Requirement already satisfied: pandas<3.0.0,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (2.2.2)
# Requirement already satisfied: pyarrow<22.0.0,>=14.0.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (21.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (2.12.3)
# Requirement already satisfied: pystemmer<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (3.1.0)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (6.0.3)
# Requirement already satisfied: searcharray<0.0.74,>=0.0.73 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (0.0.73)
# Requirement already satisfied: sentence-transformers<6.0.0,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (5.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (3.29.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (2.0.2)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (2025.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (1.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (26.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.47.0)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2026.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (0.4.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from searcharray<0.0.74,>=0.0.73->cheat_at_search==0.1.0) (3.0.12)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (5.0.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (2.10.0+cpu)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (1.16.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (3.13)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (3.13.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (1.4.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (0.24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (2.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (3.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (3.1.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (0.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (1.23.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.6.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers<6.0.0,>=5.0.0->cheat_at_search==0.1.0) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.25.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.25.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.25.0->datasets<5.0.0,>=4.8.4->cheat_at_search==0.1.0) (0.1.2)

# %% [markdown]
# ### Choose Gdrive or Instance Drive
#
# * **Save money / convenience** - set `use_grive` to True and mount your google drive. Data will be cached there. Beware of annoying permissions you need to give this notebook.
#
# * **Higher privacy / more cost** - set `use_gdrive` to False and the data will be stored as long as this notebook's runtime is running. Eventually it will be deallocated and you'll lose this cache and need to re-enter your OpenAI key when prompted.
#
# * **High privacy / save money / higher mainenance burden** - Download ipynb and run in your own Jupyter. Set the CHEAT_AT_SEARCH_DATA_PATH to some place on your system.

# %%
from cheat_at_search.data_dir import mount
mount(use_gdrive=True)    # colab, share data across notebook runs on gdrive
# mount(use_gdrive=False) # <- colab without gdrive
# mount(use_gdrive=False, manual_path="/path/to/directory")  # <- force data path to specific directory, ie you're running locally.
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Import helpers
#
# Import the following helpers:
#
# * `run_strategy` -- this runs a "strategy" and gives us the search results for each query back (more on this in a second)
# * `graded_bm25` -- a BM25 search baseline. A dump of the search results of every test query in the Wayfair dataset run using a BM25 baseline. Useful to compare our attempts against.
# * `ndcgs` -- Take one of the sets of search results (ie `graded_bm25`) and get the NDCG of each query
# * `ndcg_delta` -- Compare two sets of search results (ie `graded_bm25` vs `graded_my_cool_experiment`) and see which queries do better / worse
# * `vs_ideal` -- Take a set of search results (ie `graded_bm25`) and compare against the ideal according to the ground truth data.

# %%
from cheat_at_search.search import run_strategy, graded_bm25, ndcgs, ndcg_delta, vs_ideal

# %% [markdown]
# ## Import WANDS data
#
# Import [Wayfair Annotated Dataset](https://github.com/wayfair/WANDS) a labeled furniture e-commerce dataset. This is a helpful dataset that has 480 e-commerce queries, along with ~45K furniture / home goods products, and relevance labels for each. In WANDS relevance labels range from 0 (not at all relevant) to 2 (relevant)
#
# Below you see a sample of the corpus as a pandas dataframe.

# %%
from cheat_at_search.wands_data import products, judgments

products
# Out:
#        product_id                                       product_name  \
# 0               0                            solid wood platform bed
# 1               1                        all-clad 7 qt . slow cooker
# 2               2            all-clad electrics 6.5 qt . slow cooker
# 3               3       all-clad all professional tools pizza cutter
# 4               4  baldwin prestige alcott passage knob with roun...
# ...           ...                                                ...
# 42989       42989  malibu pressure balanced diverter fixed shower...
# 42990       42990              emmeline 5 piece breakfast dining set
# 42991       42991                      maloney 3 piece pub table set
# 42992       42992           fletcher 27.5 '' wide polyester armchair
# 42993       42993                            griffin 29 '' bar stool
#
#                              product_class  \
# 0                                     Beds
# 1                             Slow Cookers
# 2                             Slow Cookers
# 3             Slicers, Peelers And Graters
# 4                               Door Knobs
# ...                                    ...
# 42989                        Shower Panels
# 42990                    Dining Table Sets
# 42991                    Dining Table Sets
# 42992  Teen Lounge Furniture|Accent Chairs
# 42993                           Bar Stools
#
#                                       category hierarchy  \
# 0      Furniture / Bedroom Furniture / Beds & Headboa...
# 1      Kitchen & Tabletop / Small Kitchen Appliances ...
# 2      Kitchen & Tabletop / Small Kitchen Appliances ...
# 3                             Browse By Brand / All-Clad
# 4      Home Improvement / Doors & Door Hardware / Doo...
# ...                                                  ...
# 42989  Home Improvement / Bathroom Remodel & Bathroom...
# 42990  Furniture / Kitchen & Dining Furniture / Dinin...
# 42991  Furniture / Kitchen & Dining Furniture / Dinin...
# 42992  Furniture / Living Room Furniture / Chairs & S...
# 42993  Furniture / Kitchen & Dining Furniture / Bar F...
#
#                                      product_description  \
# 0      good , deep sleep can be quite difficult to ha...
# 1      create delicious slow-cooked meals , from tend...
# 2      prepare home-cooked meals on any schedule with...
# 3      this original stainless tool was designed to c...
# 4      the hardware has a rich heritage of delivering...
# ...                                                  ...
# 42989  the malibu pressure balanced diverter fixed sh...
# 42990
# 42991  this pub table set includes 1 counter height t...
# 42992  bring iconic , modern style to your space in a...
# 42993  this set of two barstools features a minimalis...
#
#                                         product_features  rating_count  \
# 0      overallwidth-sidetoside:64.7|dsprimaryproducts...          15.0
# 1      capacityquarts:7|producttype : slow cooker|pro...         100.0
# 2      features : keep warm setting|capacityquarts:6....         208.0
# 3      overallwidth-sidetoside:3.5|warrantylength : l...          69.0
# 4      compatibledoorthickness:1.375 '' |countryofori...          70.0
# ...                                                  ...           ...
# 42989  producttype : shower panel|spraypattern : rain...           3.0
# 42990  basematerialdetails : steel| : gray wood|ofhar...        1314.0
# 42991  additionaltoolsrequirednotincluded : power dri...          49.0
# 42992  legmaterialdetails : rubberwood|backheight-sea...        1746.0
# 42993  distancebetweenfloorandfootrest:7.5|dssecondar...          20.0
#
#        average_rating  review_count  \
# 0                 4.5          15.0
# 1                 2.0          98.0
# 2                 3.0         181.0
# 3                 4.5          42.0
# 4                 5.0          42.0
# ...               ...           ...
# 42989             4.5           2.0
# 42990             4.5         864.0
# 42991             4.0          41.0
# 42992             4.5        1226.0
# 42993             4.5          20.0
#
#                                                 features  doc_id  \
# 0      [overallwidth-sidetoside:64.7, dsprimaryproduc...       0
# 1      [capacityquarts:7, producttype : slow cooker, ...       1
# 2      [features : keep warm setting, capacityquarts:...       2
# 3      [overallwidth-sidetoside:3.5, warrantylength :...       3
# 4      [compatibledoorthickness:1.375 '' , countryofo...       4
# ...                                                  ...     ...
# 42989  [producttype : shower panel, spraypattern : ra...   42989
# 42990  [basematerialdetails : steel,  : gray wood, of...   42990
# 42991  [additionaltoolsrequirednotincluded : power dr...   42991
# 42992  [legmaterialdetails : rubberwood, backheight-s...   42992
# 42993  [distancebetweenfloorandfootrest:7.5, dssecond...   42993
#
#                                                    title  \
# 0                                solid wood platform bed
# 1                            all-clad 7 qt . slow cooker
# 2                all-clad electrics 6.5 qt . slow cooker
# 3           all-clad all professional tools pizza cutter
# 4      baldwin prestige alcott passage knob with roun...
# ...                                                  ...
# 42989  malibu pressure balanced diverter fixed shower...
# 42990              emmeline 5 piece breakfast dining set
# 42991                      maloney 3 piece pub table set
# 42992           fletcher 27.5 '' wide polyester armchair
# 42993                            griffin 29 '' bar stool
#
#                                              description            category  \
# 0      good , deep sleep can be quite difficult to ha...           Furniture
# 1      create delicious slow-cooked meals , from tend...  Kitchen & Tabletop
# 2      prepare home-cooked meals on any schedule with...  Kitchen & Tabletop
# 3      this original stainless tool was designed to c...     Browse By Brand
# 4      the hardware has a rich heritage of delivering...    Home Improvement
# ...                                                  ...                 ...
# 42989  the malibu pressure balanced diverter fixed sh...    Home Improvement
# 42990                                                              Furniture
# 42991  this pub table set includes 1 counter height t...           Furniture
# 42992  bring iconic , modern style to your space in a...           Furniture
# 42993  this set of two barstools features a minimalis...           Furniture
#
#                                sub_category  \
# 0                         Bedroom Furniture
# 1                  Small Kitchen Appliances
# 2                  Small Kitchen Appliances
# 3                                  All-Clad
# 4                     Doors & Door Hardware
# ...                                     ...
# 42989  Bathroom Remodel & Bathroom Fixtures
# 42990            Kitchen & Dining Furniture
# 42991            Kitchen & Dining Furniture
# 42992                 Living Room Furniture
# 42993            Kitchen & Dining Furniture
#
#                                               cat_subcat
# 0                          Furniture / Bedroom Furniture
# 1          Kitchen & Tabletop / Small Kitchen Appliances
# 2          Kitchen & Tabletop / Small Kitchen Appliances
# 3                             Browse By Brand / All-Clad
# 4               Home Improvement / Doors & Door Hardware
# ...                                                  ...
# 42989  Home Improvement / Bathroom Remodel & Bathroom...
# 42990             Furniture / Kitchen & Dining Furniture
# 42991             Furniture / Kitchen & Dining Furniture
# 42992                  Furniture / Living Room Furniture
# 42993             Furniture / Kitchen & Dining Furniture
#
# [42994 rows x 16 columns]

# %% [markdown]
# ## Synonym generation
#
# We'll first setup the scaffolding of setting up query -> synonym mapping. Expecting a list back of phrases -> their synonyms.

# %% [markdown]
# ### Pydantic Models for Structured Output
#
# ["Pydantic"](https://docs.pydantic.dev/latest/) is a Python way of having a struct or simple data class. It can be a useful way to serialize data to/from underlying data formats (ie JSON, protobuf). And we'll largely work at this level of abstraction.
#
# We're using [OpenAI's structured output](https://platform.openai.com/docs/guides/structured-outputs). Which means:
#
# * Using pydantic to define the expected output (with a description that the model can use)
# * Creating a 'struct like' view of the data we want OpenAI to produce.
# * Forcing OpenAI to return a specific format, and not begging it to return parsable JSON
#
# This pattern of using structured outputs is common across other vendors such al Ollama, Gemini, etc. Though there may be mild differences in how the pydantic types are interpreted.

# %%
from pydantic import BaseModel, Field
from typing import List
from cheat_at_search.enrich import AutoEnricher


class Query(BaseModel):
    """
    Base model for search queries, containing common query attributes.
    """
    keywords: str = Field(
        ...,
        description="The original search query keywords sent in as input"
    )


class SynonymMapping(BaseModel):
    """
    Model for mapping phrases in the query to equivalent phrases or synonyms.
    """
    phrase: str = Field(
        ...,
        description="The original phrase from the query"
    )
    synonyms: List[str] = Field(
        ...,
        description="List of synonyms or equivalent phrases for the original phrase"
    )


class QueryWithSynonyms(Query):
    """
    Extended model for search queries that includes synonyms for keywords.
    Inherits from the base Query model.
    """
    synonyms: List[SynonymMapping] = Field(
        ...,
        description="Mapping of phrases in the query to equivalent phrases or synonyms"
    )

# %%
QueryWithSynonyms.model_json_schema()
# Out:
# {'$defs': {'SynonymMapping': {'description': 'Model for mapping phrases in the query to equivalent phrases or synonyms.',
#    'properties': {'phrase': {'description': 'The original phrase from the query',
#      'title': 'Phrase',
#      'type': 'string'},
#     'synonyms': {'description': 'List of synonyms or equivalent phrases for the original phrase',
#      'items': {'type': 'string'},
#      'title': 'Synonyms',
#      'type': 'array'}},
#    'required': ['phrase', 'synonyms'],
#    'title': 'SynonymMapping',
#    'type': 'object'}},
#  'description': 'Extended model for search queries that includes synonyms for keywords.\nInherits from the base Query model.',
#  'properties': {'keywords': {'description': 'The original search query keywords sent in as input',
#    'title': 'Keywords',
#    'type': 'string'},
#   'synonyms': {'description': 'Mapping of phrases in the query to equivalent phrases or synonyms',
#    'items': {'$ref': '#/$defs/SynonymMapping'},
#    'title': 'Synonyms',
#    'type': 'array'}},
#  'required': ['keywords', 'synonyms'],
#  'title': 'QueryWithSynonyms',
#  'type': 'object'}

# %% [markdown]
# ## Direct enrichment

# %%
from cheat_at_search.data_dir import key_for_provider
from openai import OpenAI

openai_key = key_for_provider("openai")


client = OpenAI(
   api_key=openai_key,
)
prompts = []
prompts.append({"role": "system",
               "content": "You are a search query synonym generator for furniture e-commerce"})
prompts.append({"role": "user", "content": "Please generate synonyms for query: suede couch"})

response = client.responses.parse(
   model="gpt-4o",
   input=prompts,
   text_format=QueryWithSynonyms
)

response.output_parsed
# Out:
# QueryWithSynonyms(keywords='suede couch', synonyms=[SynonymMapping(phrase='suede', synonyms=['microfiber', 'soft leather', 'faux suede', 'velvet-like']), SynonymMapping(phrase='couch', synonyms=['sofa', 'settee', 'loveseat', 'divan'])])

# %% [markdown]
# ### Synonym generation code
#
# We use `AutoEnricher` in this class. This is something that wraps the calls to OpenAI in the `cheat_at_search` package.
#
# Notice when constructing it, we provide three values:
#
# * `model` -- the underlying LLM to use. If you load ChatGPT, you would notice the dropdown of models you can select. They each have pros/cons with cost and quality.
# * `system_prompt` -- the general behavior of the agent, priming it for the task its about to perform
# * `response_model` -- the Pydantic class to use to generate structured outputs
#
# We can then call `enricher.enrich(prompt)` and get back an instance of `QueryWithSynonyms`
#
# Notice too `get_prompt` generates a prompt given a search query.

# %%
syn_enricher = AutoEnricher(model="openai/gpt-5-nano",
                            system_prompt="You are a helpful AI assistant extracting synonyms from queries.",
                            response_model=QueryWithSynonyms)

def get_prompt(query: str):
    prompt = f"""
        Extract synonyms from the following query that will help us find relevant products for the query.

        {query}
    """

    return prompt

print(get_prompt("rack glass"))
# Out:
#         Extract synonyms from the following query that will help us find relevant products for the query.
#
#         rack glass

# %%
def query_to_syn(query: str):
    return syn_enricher.enrich(get_prompt(query))

query_to_syn("foldout blue ugly love seat")
# Out:
# QueryWithSynonyms(keywords='foldout blue ugly love seat', synonyms=[SynonymMapping(phrase='foldout', synonyms=['pull-out', 'sofa bed', 'futon bed', 'convertible sofa']), SynonymMapping(phrase='blue', synonyms=['navy blue', 'azure', 'cobalt', 'blue color', 'blue shade', 'blue upholstery']), SynonymMapping(phrase='ugly', synonyms=['unattractive', 'unsightly', 'plain', 'hideous', 'unappealing', 'dull']), SynonymMapping(phrase='love seat', synonyms=['loveseat', 'two-seater sofa', 'smaller sofa', 'duo-seater'])])

# %% [markdown]
# ### Snowball tokenizer
#
# We'll use a [snowball stemmer](https://www.nltk.org/api/nltk.stem.SnowballStemmer.html) when we index the data. This is just a function that takes a string and returns a list of tokens, each snowball stemmed.

# %%
from cheat_at_search.tokenizers import snowball_tokenizer
snowball_tokenizer("fancy furniture")
# Out:
# ['fanci', 'furnitur']

# %% [markdown]
# ### Build a SearchStrategy -- Enrich, index, search
#
# A SearchStrategy emulates a typical search system, but in a mini form suitable for dorking around in this notebook.
#
# Notice in `__init__`, indexing:
#
# ```
#     self.index['product_name_snowball'] = SearchArray.index(
#             products['product_name'],
#             snowball_tokenizer
#         )
# ```
#
# Then later we `search`, summing up BM25 scores across different fields:
#
# ```
#         # ***
#         # For each token, get the BM25 score of that token in product name and
#         # product description. Sum them
#         for token in tokenized:
#             bm25_scores += self.name_boost * self.index['product_name_snowball'].array.score(token)
#             bm25_scores += self.description_boost * self.index['product_description_snowball'].array.score(
#                 token)
# ```
#
# Farther down, you see we boost also when we match a synonym phrase.
#
# #### SearchArray
#
# We use a lexical search library [SearchArray](http://github.com/softwaredoug/search-array) for simple lexical searches. (See the notebooks and information in the prework for the class)
#
# In the case of synonyms, a lot of teams trying this have a mature lexical search system like Elasticsearch. Instead of adding embedding retrieval to the search, they try this hack to see if they can cheat at search.

# %%
from searcharray import SearchArray
from cheat_at_search.strategy.strategy import SearchStrategy
import numpy as np


class SynonymSearch(SearchStrategy):
    def __init__(self, products, synonym_generator,
                 name_boost=9.3,
                 description_boost=4.1):
        """ Build an index."""
        super().__init__(products)
        self.index = products
        self.name_boost = name_boost
        self.description_boost = description_boost

        #*****
        # Take an array of text (here `products['product_name']`)
        # Tokenize it with snowball (the passed function)
        # Produce a searchable index on "product_name_snowball"
        self.index['product_name_snowball'] = SearchArray.index(
            products['product_name'],
            snowball_tokenizer
        )
        self.index['product_description_snowball'] = SearchArray.index(
            products['product_description'], snowball_tokenizer)
        self.query_to_syn = synonym_generator

    def search(self, query, k=10):
        """Dumb baseline lexical search with LLM generated synonyms"""
        # ***
        # Tokenize the query with snowball
        tokenized = snowball_tokenizer(query)
        bm25_scores = np.zeros(len(self.index))

        # ***
        # For each token, get the BM25 score of that token in product name and
        # product description. Sum them
        for token in tokenized:
            bm25_scores += self.name_boost * self.index['product_name_snowball'].array.score(token)
            bm25_scores += self.description_boost * self.index['product_description_snowball'].array.score(
                token)

        # ***
        # Generate synonyms
        synonyms = self.query_to_syn(query)

        # ***
        # Boost by each synonym phrase
        # (repeat the same above, except we add the BM25 scores of the generated synonyms)
        all_single_tokens = set()
        for mapping in synonyms.synonyms:
            for phrase in mapping.synonyms:
                tokenized = snowball_tokenizer(phrase)
                bm25_scores += self.index['product_name_snowball'].array.score(tokenized)
                bm25_scores += self.index['product_description_snowball'].array.score(tokenized)
                for token in tokenized:
                    all_single_tokens.add(token)

        # ***
        # Boost by each single token
        # for token in all_single_tokens:
        #     bm25_scores += self.index['product_name_snowball'].array.score(token)
        #     bm25_scores += self.index['product_description_snowball'].array.score(token)

        # ***
        # Sort by BM25 scores
        top_k = np.argsort(-bm25_scores)[:k]
        scores = bm25_scores[top_k]

        return top_k, scores


syns = SynonymSearch(products, query_to_syn)
# Out:
# 2026-05-22 12:52:08,264 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2026-05-22 12:52:08,303 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2026-05-22 12:52:08,321 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2026-05-22 12:52:09,606 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2026-05-22 12:52:10,450 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2026-05-22 12:52:11,053 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2026-05-22 12:52:11,777 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2026-05-22 12:52:12,350 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2026-05-22 12:52:12,360 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2026-05-22 12:52:12,376 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2026-05-22 12:52:12,445 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2026-05-22 12:52:12,554 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2026-05-22 12:52:12,558 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2026-05-22 12:52:12,626 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete
# 2026-05-22 12:52:12,671 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2026-05-22 12:52:12,697 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2026-05-22 12:52:12,703 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2026-05-22 12:52:14,116 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2026-05-22 12:52:15,180 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2026-05-22 12:52:16,255 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2026-05-22 12:52:17,326 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2026-05-22 12:52:17,812 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2026-05-22 12:52:17,842 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2026-05-22 12:52:17,870 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2026-05-22 12:52:18,390 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2026-05-22 12:52:18,645 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2026-05-22 12:52:18,647 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2026-05-22 12:52:18,820 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete

# %% [markdown]
# ### Run strategy, get results back
#
# We call `run_strategy` which behind the scene passes every WANDS query to the `syns` strategy to get search results. Then appends them all to `graded_syns` which has 480 queries times 10 results per query (4800 rows)

# %%
# for each query
#   results = syns.search(query)
#   -- Give each result a 'grade'
#   --- Compute DCG
graded_syns = run_strategy(syns, judgments)
graded_syns
# Out:
# Searching: 100%|██████████| 480/480 [00:10<00:00, 44.84it/s]
#       product_id                                       product_name  \
# 0           9709    certified international gather oval baking dish
# 1          26644      international harvester melamine serving tray
# 2           9707  certified international piazzette 3d villa sal...
# 3           9702  certified international cactus verde 3d salt a...
# 4           9706  certified international urban farmhouse 3d sal...
# ...          ...                                                ...
# 4795        2207                         flamingo magnet wall décor
# 4796       17391                 rondon a pink flamingo paper print
# 4797        3267         flamingos green by cat coquillette - print
# 4798       13948  cervantes whimsical flamingo & pineapple micro...
# 4799        2777                 flamingo- unframed print on canvas
#
#                                     product_class  \
# 0                                             NaN
# 1     Serving Dishes & Platters|Licensed Products
# 2      Salt And Pepper Shakers / Grinders (Mills)
# 3      Salt And Pepper Shakers / Grinders (Mills)
# 4                                             NaN
# ...                                           ...
# 4795                                   Wall Décor
# 4796                              Kids Wall Décor
# 4797                                     Wall Art
# 4798                        Sheets And Sheet Sets
# 4799                                     Wall Art
#
#                                      category hierarchy  \
# 0     Kitchen & Tabletop / Cookware & Bakeware / Bak...
# 1     Kitchen & Tabletop / Tableware & Drinkware / S...
# 2     Kitchen & Tabletop / Tableware & Drinkware / S...
# 3     Kitchen & Tabletop / Tableware & Drinkware / S...
# 4     Kitchen & Tabletop / Tableware & Drinkware / S...
# ...                                                 ...
# 4795  Sale / Closeout / Wall Accents / Blue Wall Acc...
# 4796  Baby & Kids / Baby & Kids Décor & Lighting / A...
# 4797  Décor & Pillows / Art / All Wall Art / Green W...
# 4798        Bed & Bath / Bedding / Sheets & Pillowcases
# 4799               Décor & Pillows / Art / All Wall Art
#
#                                     product_description  \
# 0     simple crockery with the look of hand-thrown p...
# 1     this case ih serving tray is a perfect additio...
# 2
# 3
# 4
# ...                                                 ...
# 4795  this beautifully handcrafted flamingo wooden d...
# 4796  perfect for the nursery or a little girl 's be...
# 4797  showcasing a pair of flamingos encircled by ve...
# 4798  a great whimsical print of flamingo and pineap...
# 4799  bay isle home 15 '' x30 '' flamingo i & ii set...
#
#                                        product_features  rating_count  \
# 0     overalllength-endtoend:14.25|productcare : dis...           2.0
# 1     overalllength-endtoend:11.5|pattern : no patte...           NaN
# 2     productweight:1.5|trend : novelty|productcare ...          15.0
# 3     color : green|refilltype : screw off top|produ...           NaN
# 4     producttype : salt and pepper shaker set|prima...           3.0
# ...                                                 ...           ...
# 4795  productcare : wipe clean with a dry cloth . do...           NaN
# 4796  gender : girl / woman+|primarymaterialdetails ...           1.0
# 4797  holidayoccasion : no holiday|shape : square|co...           1.0
# 4798  fittedsheetlength-headtotoe:80|flatsheetwidth-...          12.0
# 4799  foodbeverage : not food & beverage|orientation...           NaN
#
#       average_rating  review_count  \
# 0                5.0           1.0
# 1                NaN           NaN
# 2                5.0          12.0
# 3                NaN           NaN
# 4                3.5           3.0
# ...              ...           ...
# 4795             NaN           NaN
# 4796             5.0           1.0
# 4797             4.0           1.0
# 4798             5.0          11.0
# 4799             NaN           NaN
#
#                                                features  ...      score  \
# 0     [overalllength-endtoend:14.25, productcare : d...  ...  73.322339
# 1     [overalllength-endtoend:11.5, pattern : no pat...  ...  69.644272
# 2     [productweight:1.5, trend : novelty, productca...  ...  61.392514
# 3     [color : green, refilltype : screw off top, pr...  ...  58.234200
# 4     [producttype : salt and pepper shaker set, pri...  ...  58.234200
# ...                                                 ...  ...        ...
# 4795  [productcare : wipe clean with a dry cloth . d...  ...  50.694689
# 4796  [gender : girl / woman+, primarymaterialdetail...  ...  48.986856
# 4797  [holidayoccasion : no holiday, shape : square,...  ...  48.481298
# 4798  [fittedsheetlength-headtotoe:80, flatsheetwidt...  ...  45.647358
# 4799  [foodbeverage : not food & beverage, orientati...  ...  45.176806
#
#                                  query query_id rank grade discounted_gain  \
# 0     certified international melamine       73    1   1.0        1.000000
# 1     certified international melamine       73    2   1.0        0.500000
# 2     certified international melamine       73    3   1.0        0.333333
# 3     certified international melamine       73    4   1.0        0.250000
# 4     certified international melamine       73    5   1.0        0.200000
# ...                                ...      ...  ...   ...             ...
# 4795                          flamingo      102    6   2.0        0.500000
# 4796                          flamingo      102    7   2.0        0.428571
# 4797                          flamingo      102    8   2.0        0.375000
# 4798                          flamingo      102    9   2.0        0.333333
# 4799                          flamingo      102   10   2.0        0.300000
#
#           idcg       dcg      ndcg  mrr
# 0     8.786905  2.928968  0.333333  0.0
# 1     8.786905  2.928968  0.333333  0.0
# 2     8.786905  2.928968  0.333333  0.0
# 3     8.786905  2.928968  0.333333  0.0
# 4     8.786905  2.928968  0.333333  0.0
# ...        ...       ...       ...  ...
# 4795  8.786905  8.786905  1.000000  1.0
# 4796  8.786905  8.786905  1.000000  1.0
# 4797  8.786905  8.786905  1.000000  1.0
# 4798  8.786905  8.786905  1.000000  1.0
# 4799  8.786905  8.786905  1.000000  1.0
#
# [4800 rows x 26 columns]

# %% [markdown]
# ### Look at one search result...

# %%
graded_syns[graded_syns['query'] == "wood bar stools"]
# Out:
#      product_id                               product_name product_class  \
# 530       17625       adona solid wood bar & counter stool    Bar Stools
# 531       39984             solid wood bar & counter stool    Bar Stools
# 532       24132   bergstrom solid wood bar & counter stool    Bar Stools
# 533        4888  gollapalli solid wood bar & counter stool    Bar Stools
# 534        5105     peatman solid wood counter & bar stool    Bar Stools
# 535       18577              pala wood bar & counter stool    Bar Stools
# 536       39979   evelino solid wood counter and bar stool    Bar Stools
# 537       37300    axelle solid wood bar and counter stool    Bar Stools
# 538        4884  abramowitz solid wood bar & counter stool    Bar Stools
# 539       34277   crystelle solid wood bar & counter stool    Bar Stools
#
#                                     category hierarchy  \
# 530  Furniture / Kitchen & Dining Furniture / Bar F...
# 531  Furniture / Kitchen & Dining Furniture / Bar F...
# 532  Furniture / Kitchen & Dining Furniture / Bar F...
# 533  Furniture / Kitchen & Dining Furniture / Bar F...
# 534  Furniture / Kitchen & Dining Furniture / Bar F...
# 535  Furniture / Kitchen & Dining Furniture / Bar F...
# 536  Furniture / Kitchen & Dining Furniture / Bar F...
# 537  Furniture / Kitchen & Dining Furniture / Bar F...
# 538  Furniture / Kitchen & Dining Furniture / Bar F...
# 539  Furniture / Kitchen & Dining Furniture / Bar F...
#
#                                    product_description  \
# 530  this classic bar stool is solid wood for firm ...
# 531  outfit the home bar or accent your favorite se...
# 532  these solid wood bar stools add a contemporary...
# 533  enhance the beauty of your home with the inclu...
# 534  this set of two bar stools is a great addition...
# 535  this stool is an exclusive counter and bar wit...
# 536  spruce up your kitchen , breakfast , or den wi...
# 537  this bar & counter stool is a sublime stool fu...
# 538  give yourself a place to sit right next to you...
# 539  this crystelle solid wood bar & counter stool ...
#
#                                       product_features  rating_count  \
# 530  levelofassembly : partial assembly|overalldept...           3.0
# 531  overalldepth-fronttoback:13.4|dsprimaryproduct...         330.0
# 532  seatdepth-fronttoback:13|legbasetype:4 legs|se...         207.0
# 533  upholsterymaterial : faux leather|seatbacktype...           NaN
# 534  seatbacktype : backless|productcare : do not u...           2.0
# 535  supplierintendedandapproveduse : non residenti...           5.0
# 536  seatwidth-sidetoside:13.58|legbasetype:4 legs|...         231.0
# 537  dswoodtone : medium wood|seatmaterialdetails :...         298.0
# 538  overallproductweight:15.84|framematerial : sol...           NaN
# 539  dssecondaryproductstyle : contemporary industr...          21.0
#
#      average_rating  review_count  \
# 530             4.0           3.0
# 531             4.5         253.0
# 532             5.0         154.0
# 533             NaN           NaN
# 534             4.5           2.0
# 535             5.0           5.0
# 536             4.5         144.0
# 537             4.5         203.0
# 538             NaN           NaN
# 539             4.5          17.0
#
#                                               features  ...      score  \
# 530  [levelofassembly : partial assembly, overallde...  ...  66.594088
# 531  [overalldepth-fronttoback:13.4, dsprimaryprodu...  ...  66.542115
# 532  [seatdepth-fronttoback:13, legbasetype:4 legs,...  ...  66.494473
# 533  [upholsterymaterial : faux leather, seatbackty...  ...  66.376257
# 534  [seatbacktype : backless, productcare : do not...  ...  65.998547
# 535  [supplierintendedandapproveduse : non resident...  ...  65.768304
# 536  [seatwidth-sidetoside:13.58, legbasetype:4 leg...  ...  65.629890
# 537  [dswoodtone : medium wood, seatmaterialdetails...  ...  65.564730
# 538  [overallproductweight:15.84, framematerial : s...  ...  65.445647
# 539  [dssecondaryproductstyle : contemporary indust...  ...  64.735635
#
#                query query_id rank grade discounted_gain      idcg       dcg  \
# 530  wood bar stools      440    1   2.0        3.000000  8.786905  7.503571
# 531  wood bar stools      440    2   2.0        1.500000  8.786905  7.503571
# 532  wood bar stools      440    3   2.0        1.000000  8.786905  7.503571
# 533  wood bar stools      440    4   1.0        0.250000  8.786905  7.503571
# 534  wood bar stools      440    5   2.0        0.600000  8.786905  7.503571
# 535  wood bar stools      440    6   1.0        0.166667  8.786905  7.503571
# 536  wood bar stools      440    7   2.0        0.428571  8.786905  7.503571
# 537  wood bar stools      440    8   1.0        0.125000  8.786905  7.503571
# 538  wood bar stools      440    9   2.0        0.333333  8.786905  7.503571
# 539  wood bar stools      440   10   1.0        0.100000  8.786905  7.503571
#
#          ndcg  mrr
# 530  0.853949  1.0
# 531  0.853949  1.0
# 532  0.853949  1.0
# 533  0.853949  1.0
# 534  0.853949  1.0
# 535  0.853949  1.0
# 536  0.853949  1.0
# 537  0.853949  1.0
# 538  0.853949  1.0
# 539  0.853949  1.0
#
# [10 rows x 26 columns]

# %%
query_to_syn("wood bar stools")
# Out:
# QueryWithSynonyms(keywords='wood bar stools', synonyms=[SynonymMapping(phrase='wood bar stools', synonyms=['wooden bar stools', 'timber bar stools', 'wood barseat stools', 'wood bar-height stools', 'wood barstools', 'wooden counter stools', 'wood counter height stools', 'rustic wood bar stools', 'oak bar stools', 'pine bar stools'])])

# %% [markdown]
# ## Analyze the results
#
# Let's look at the results to see how we did against a BM25 baseline
#
# Here we get ndcg of each query with `ndcgs`, then compute the mean for all queries. We do this comparing BM25 vs our synonym variant

# %%
ndcgs(graded_bm25).mean(), ndcgs(graded_syns).mean()
# Out:
# (np.float64(0.5411098691836396), np.float64(0.5507093099399358))

# %% [markdown]
# ### Win / loss against BM25 baseline
#
# `ndcg_delta` shows us the per-query NDCG difference
#
# * We note some massive wins
# * We unfortunately also note massive variance in outcomes (meaning a risky change)

# %%
ndcg_delta(graded_syns, graded_bm25)
# Out:
# query
# midcentury tv unit                 0.665763
# cover set for outdoor furniture    0.452965
# 7qt slow cooker                    0.446371
# bathroom vanity knobs              0.409701
# desk for kids                      0.315811
#                                      ...
# closet storage with zipper        -0.131825
# adjustable height artist stool    -0.151741
# bathroom single faucet            -0.181547
# king size bed                     -0.287901
# capricorn chest                   -0.292734
# Name: ndcg, Length: 181, dtype: float64

# %% [markdown]
# ### Examine a single query (what went right/wrong?)
#
# First we see what BM25 produced...

# %%
QUERY = "seat cushions desk"

# %%
graded_bm25[graded_bm25['query'] == QUERY][['rank', 'product_name', 'product_description', 'grade']]
# Out:
#       rank                        product_name  \
# 2930     1  ergonomic memory foam seat cushion
# 2931     2               chiavari seat cushion
# 2932     3                 deluxe seat cushion
# 2933     4           deep outdoor seat cushion
# 2934     5                outdoor seat cushion
# 2935     6                 indoor seat cushion
# 2936     7         indoor/outdoor seat cushion
# 2937     8           outdoor seat/back cushion
# 2938     9      outdoor sunbrella seat cushion
# 2939    10                    gel seat cushion
#
#                                     product_description  grade
# 2930  work and drive in absolute comfort with the er...    2.0
# 2931  hard cushions are the most popular choice in t...    1.0
# 2932  the deluxe seat and back cushion by sacro-ease...    1.0
# 2933  this seat & back deep seating cushions feature...    1.0
# 2934  add personality and comfort to your outdoor pa...    1.0
# 2935  the classic buffalo check pattern comes to lif...    1.0
# 2936  become your own personal designer with their f...    1.0
# 2937  this seat and back cushion adds a boost of sof...    1.0
# 2938  this outdoor wicker seat cushion is made for c...    0.0
# 2939  sleekly designed with an ergonomic shape for r...    2.0

# %%
graded_syns[graded_syns['query'] ==  QUERY][['rank', 'product_name', 'product_description', 'grade']]
# Out:
#       rank                        product_name  \
# 4540     1  ergonomic memory foam seat cushion
# 4541     2           deep outdoor seat cushion
# 4542     3                outdoor seat cushion
# 4543     4                 indoor seat cushion
# 4544     5               chiavari seat cushion
# 4545     6                 deluxe seat cushion
# 4546     7         indoor/outdoor seat cushion
# 4547     8          ergonomic gel seat cushion
# 4548     9                    gel seat cushion
# 4549    10         devrek outdoor seat cushion
#
#                                     product_description  grade
# 4540  work and drive in absolute comfort with the er...    2.0
# 4541  this seat & back deep seating cushions feature...    1.0
# 4542  add personality and comfort to your outdoor pa...    1.0
# 4543  the classic buffalo check pattern comes to lif...    1.0
# 4544  hard cushions are the most popular choice in t...    1.0
# 4545  the deluxe seat and back cushion by sacro-ease...    1.0
# 4546  become your own personal designer with their f...    1.0
# 4547  support your seat using the gel cushion . sitt...    2.0
# 4548  sleekly designed with an ergonomic shape for r...    2.0
# 4549  the smoky gray tone of this outdoor oversized ...    1.0

# %%
against_ideal = vs_ideal(graded_syns, judgments, products)
against_ideal[against_ideal['query'] == QUERY]
# Out:
#       query_id               query  doc_id_ideal  grade_ideal  rank_ideal  \
# 4540       297  seat cushions desk        6263.0          2.0         1.0
# 4541       297  seat cushions desk       11134.0          2.0         2.0
# 4542       297  seat cushions desk       15659.0          2.0         3.0
# 4543       297  seat cushions desk       27626.0          2.0         4.0
# 4544       297  seat cushions desk       27635.0          2.0         5.0
# 4545       297  seat cushions desk       30395.0          2.0         6.0
# 4546       297  seat cushions desk       32638.0          2.0         7.0
# 4547       297  seat cushions desk       39975.0          2.0         8.0
# 4548       297  seat cushions desk         198.0          1.0         9.0
# 4549       297  seat cushions desk         202.0          1.0        10.0
#
#                                            title_ideal  \
# 4540                        amamedic mesh seat cushion
# 4541                              yeslife seat cushion
# 4542                         office chair seat cushion
# 4543  pressure relief non-slip orthopedic seat cushion
# 4544                        ergonomic gel seat cushion
# 4545    creative office pillow plush back seat cushion
# 4546                                  gel seat cushion
# 4547                ergonomic memory foam seat cushion
# 4548                              indoor chair cushion
# 4549                         chair indoor seat cushion
#
#                             title_actual  rank_actual  doc_id_actual  \
# 4540  ergonomic memory foam seat cushion            1          39975
# 4541           deep outdoor seat cushion            2          10294
# 4542                outdoor seat cushion            3           9648
# 4543                 indoor seat cushion            4           5542
# 4544               chiavari seat cushion            5          28919
# 4545                 deluxe seat cushion            6          25206
# 4546         indoor/outdoor seat cushion            7          20124
# 4547          ergonomic gel seat cushion            8          27635
# 4548                    gel seat cushion            9          32638
# 4549         devrek outdoor seat cushion           10          30768
#
#       grade_actual      dcg      ndcg
# 4540           2.0  5.40119  0.614686
# 4541           1.0  5.40119  0.614686
# 4542           1.0  5.40119  0.614686
# 4543           1.0  5.40119  0.614686
# 4544           1.0  5.40119  0.614686
# 4545           1.0  5.40119  0.614686
# 4546           1.0  5.40119  0.614686
# 4547           2.0  5.40119  0.614686
# 4548           2.0  5.40119  0.614686
# 4549           1.0  5.40119  0.614686

# %%
query_to_syn(QUERY)
# Out:
# QueryWithSynonyms(keywords='seat cushions desk', synonyms=[SynonymMapping(phrase='seat cushions desk', synonyms=['seat cushions', 'desk cushions', 'chair cushions', 'cushions for seat', 'office chair cushions', 'desk chair cushions', 'seat pads', 'desk pad cushions'])])
